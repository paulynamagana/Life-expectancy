# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.layers import InputLayer, Dense
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## Import dataset

# %%
dataset = pd.read_csv("life_expectancy.csv", )
dataset.head() #inspect the data
# Out:
#        Country  Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 0  Afghanistan  2015  Developing            263.0             62     0.01
# 1  Afghanistan  2014  Developing            271.0             64     0.01
# 2  Afghanistan  2013  Developing            268.0             66     0.01
# 3  Afghanistan  2012  Developing            272.0             69     0.01
# 4  Afghanistan  2011  Developing            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 0               71.279624         65.0      1154   19.1  ...
# 1               73.523582         62.0       492   18.6  ...
# 2               73.219243         64.0       430   18.1  ...
# 3               78.184215         67.0      2787   17.6  ...
# 4                7.097109         68.0      3013   17.2  ...
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0               8.16         65.0        0.1  584.259210  33736494.0
# ...

# %%
#get stas from the data
dataset.describe()
# Out:
#               Year  Adult Mortality  infant deaths      Alcohol  \
# count  2938.000000      2938.000000    2938.000000  2938.000000
# mean   2007.518720       164.725664      30.303948     4.546875
# std       4.613841       124.086215     117.926501     3.921946
# min    2000.000000         1.000000       0.000000     0.010000
# 25%    2004.000000        74.000000       0.000000     1.092500
# 50%    2008.000000       144.000000       3.000000     3.755000
# 75%    2012.000000       227.000000      22.000000     7.390000
# max    2015.000000       723.000000    1800.000000    17.870000
#
#        percentage expenditure  Hepatitis B       Measles          BMI   \
# count             2938.000000  2938.000000    2938.000000  2938.000000
# mean               738.251295    83.022124    2419.592240    38.381178
# std               1987.914858    22.996984   11467.272489    19.935375
# min                  0.000000     1.000000       0.000000     1.000000
# ...

# %% [markdown]
# Year, we can see the data goes from 2000 to 2015

# %%
dataset.drop(["Country"], axis=1, inplace=True)

# %%
labels = dataset.iloc[:,-1] #extract labels, life expectancy
features = dataset.iloc[:,0:-1]

# %%
features = pd.get_dummies(features)
features.head()
# Out:
#    Year  Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 0  2015            263.0             62     0.01               71.279624
# 1  2014            271.0             64     0.01               73.523582
# 2  2013            268.0             66     0.01               73.219243
# 3  2012            272.0             69     0.01               78.184215
# 4  2011            275.0             71     0.01                7.097109
#
#    Hepatitis B  Measles    BMI   under-five deaths   Polio  ...  Diphtheria   \
# 0         65.0      1154   19.1                  83    6.0  ...         65.0
# 1         62.0       492   18.6                  86   58.0  ...         62.0
# 2         64.0       430   18.1                  89   62.0  ...         64.0
# 3         67.0      2787   17.6                  93   67.0  ...         67.0
# 4         68.0      3013   17.2                  97   68.0  ...         68.0
#
#     HIV/AIDS         GDP  Population   thinness  1-19 years  \
# ...

# %%
features_train, features_test, labels_train, labels_test = train_test_split(features, labels, test_size=0.20, random_state=23)

# %%
numerical_features = features.select_dtypes(include=["float64", "int64"])
numerical_columns = numerical_features.columns
ct = ColumnTransformer([("scaler", StandardScaler(), numerical_columns)], remainder = "passthrough")

# %%
features_train_scaled = ct.fit_transform(features_train)
features_test_scaled = ct.transform(features_test)

# %%
my_model = Sequential()

# %%
num_features = features.shape[1]
input = InputLayer(input_shape = (num_features,))
my_model.add(input)
my_model.add(Dense(64, activation="relu"))
my_model.add(Dense(1))
my_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 64)                1408
#
#  dense_4 (Dense)             (None, 1)                 65
#
# ...
# Total params: 1,473
# Trainable params: 1,473
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = Adam(learning_rate= 0.01)
my_model.compile(loss="mse", metrics = ["mae"], optimizer=opt)

# %%
my_model.fit(features_train_scaled, labels_train, epochs = 40, batch_size= 1, verbose=1)
# Out:
# Epoch 1/40
# 2350/2350 [==============================] - 5s 2ms/step - loss: 148.4267 - mae: 6.4098
# Epoch 2/40
# 2350/2350 [==============================] - 10s 4ms/step - loss: 28.3405 - mae: 3.8582
# Epoch 3/40
# 2350/2350 [==============================] - 12s 5ms/step - loss: 23.9435 - mae: 3.6043
# Epoch 4/40
# 2350/2350 [==============================] - 12s 5ms/step - loss: 26.3183 - mae: 3.5402
# Epoch 5/40
# 2350/2350 [==============================] - 12s 5ms/step - loss: 16.9777 - mae: 3.0650
# Epoch 6/40
# 2350/2350 [==============================] - 10s 4ms/step - loss: 16.7068 - mae: 2.9091
# Epoch 7/40
# 2350/2350 [==============================] - 8s 3ms/step - loss: 16.7942 - mae: 3.0135
# Epoch 8/40
# 2350/2350 [==============================] - 9s 4ms/step - loss: 16.5034 - mae: 2.8676
# Epoch 9/40
# 2350/2350 [==============================] - 8s 3ms/step - loss: 14.0445 - mae: 2.7084
# Epoch 10/40
# ...

# %%
res_mse, res_mae = my_model.evaluate(features_test_scaled, labels_test, verbose=0)

# %%
print("MAE: ", res_mae)
print("RMSE: ", res_mse)
# Out:
# MAE:  1.906838297843933
# RMSE:  7.192779541015625
